# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pl

# %%
ls ../../../data/bank-4
# Out:
# data-desc.txt  test.csv       train.csv

# %%
train = pd.read_csv(
    '../../../data/bank-4/train.csv',
    names = ['age', 'job', 'marital', 'education', 'default', 'balance', 'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays', 'previous', 'poutcome', 'y']
)

# %%
train
# Out:
#       age          job   marital  education default  balance housing loan  \
# 0      41     services   married  secondary      no        0     yes   no
# 1      48  blue-collar    single  secondary      no      312     yes  yes
# 2      55   technician   married  secondary      no     1938      no  yes
# 3      54       admin.   married   tertiary      no       59     yes   no
# 4      34   management    single   tertiary      no     2646      no   no
# ...   ...          ...       ...        ...     ...      ...     ...  ...
# 4995   50   technician  divorced  secondary      no      116     yes   no
# 4996   59   management  divorced   tertiary      no      258     yes   no
# 4997   37  blue-collar   married  secondary      no      151     yes   no
# 4998   31   management    single   tertiary      no     1315     yes   no
# 4999   28  blue-collar   married  secondary      no      339     yes   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
train_values = {
    'age': ['< 50 precentile', '> 50 precentile'],
    'job': ["admin.","unknown","unemployed","management","housemaid","entrepreneur","student", "blue-collar","self-employed","retired","technician","services"],
    'marital': ["married","divorced","single"],
    'education': ["unknown","secondary","primary","tertiary"],
    'default': ["yes","no"],
    'balance': ['< 50 precentile', '> 50 precentile'],
    'housing': ["yes","no"],
    'loan': ["yes","no"],
    'contact': ["unknown","telephone","cellular"],
    'day': ['< 50 precentile', '> 50 precentile'],
    'month': ['apr', 'aug', 'dec', 'feb', 'jan', 'jul', 'jun', 'mar', 'may', 'nov', 'oct', 'sep'],
    'duration': ['< 50 precentile', '> 50 precentile'],
    'campaign': ['< 50 precentile', '> 50 precentile'],
    'pdays': ['not previously contacted', '< 50 precentile', '> 50 precentile'],
    'previous': ['< 50 precentile', '> 50 precentile'],
    'poutcome': ["unknown","other","failure","success"],
    'y': ["yes","no"]
}
# train_values

# %%
median_age = np.median(train.age)
median_balance = np.median(train.balance)
median_day = np.median(train.day)
median_duration = np.median(train.duration)
median_campaign = np.median(train.campaign)
median_pdays = np.median(train.pdays[train.pdays!=-1])
median_previous = np.median(train.previous)
train_discretized = pd.DataFrame(
    {
        'age': [ '< 50 precentile' if age>median_age else '> 50 precentile' for age in train.age],
        'job': train.job,
        'marital': train.marital,
        'education': train.education,
        'default': train.default,
        'balance': [ '< 50 precentile' if balance>median_balance else '> 50 precentile' for balance in train.balance],
        'housing': train.housing,
        'loan': train.loan,
        'contact': train.contact,
        'day': [ '< 50 precentile' if day>median_day else '> 50 precentile' for day in train.day],
        'month': train.month,
        'duration': [ '< 50 precentile' if duration>median_duration else '> 50 precentile' for duration in train.duration],
        'campaign': [ '< 50 precentile' if campaign>median_campaign else '> 50 precentile' for campaign in train.campaign],
        'pdays': [ 'not previously contacted' if pdays==-1 else ('< 50 precentile' if pdays>median_pdays else '> 50 precentile') for pdays in train.pdays],
        'previous': [ '< 50 precentile' if previous>median_previous else '> 50 precentile' for previous in train.previous],
        'poutcome': train.poutcome,
        'y': train.y
    }
)
train_discretized
# Out:
#                   age          job   marital  education default  \
# 0     < 50 precentile     services   married  secondary      no
# 1     < 50 precentile  blue-collar    single  secondary      no
# 2     < 50 precentile   technician   married  secondary      no
# 3     < 50 precentile       admin.   married   tertiary      no
# 4     > 50 precentile   management    single   tertiary      no
# ...               ...          ...       ...        ...     ...
# 4995  < 50 precentile   technician  divorced  secondary      no
# 4996  < 50 precentile   management  divorced   tertiary      no
# 4997  > 50 precentile  blue-collar   married  secondary      no
# 4998  > 50 precentile   management    single   tertiary      no
# 4999  > 50 precentile  blue-collar   married  secondary      no
#
#               balance housing loan    contact              day month  \
# 0     > 50 precentile     yes   no    unknown  > 50 precentile   may
# ...
